# %% [markdown]
# # Teste do Jupiter

# %%
print("Meu codigo no Jupyter")
# Out:
# Meu codigo no Jupyter

# %% [markdown]
# ## Instalando o Pandas no Jupyter
#
# - Obs: podemos usar o termina do VS Code para instalar também, só usar o comando "pip install pandas" sem o "!"

# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.4/11.5 MB 11.8 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/11.5 MB 10.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.5 MB 10.1 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/11.5 MB 10.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.6/11.5 MB 10.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.5 MB 10.6 MB/s eta 0:00:01
#    ------------ --------------------------- 3.5/11.5 MB 10.6 MB/s eta 0:00:01
#    ------------- -------------------------- 3.9/11.5 MB 10.4 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.5 MB 10.3 MB/s eta 0:00:01
# ...

# %% [markdown]
# ### Usando o import para reduzir o codigo

# %%
import pandas as pd

# %%
tabela  = pd.DataFrame ({"Nome": ["Joao", "Victor"], "Idade":[29, 30]})
display(tabela)
# Out:
#      Nome  Idade
# 0    Joao     29
# 1  Victor     30
